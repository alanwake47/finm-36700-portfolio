# %% [markdown]
# # 2 Mean-Variance Optimization
#
# - The time-series data gives monthly returns for the 11 asset classes and a short-term Treasury-bill
# fund return, (“SHV”,) which we consider as the risk-free rate.
# - The data is provided in total returns, (in which case you should ignore the SHV column,) as
# well as excess returns, (where SHV has been subtracted from the other columns.)
# - These are nominal returns—they are not adjusted for inflation, and in our calculations we are not making any adjustment for inflation.

# %%
import pandas as pd
import numpy as np
import math as m

# %%
ret = pd.read_excel('multi_asset_etf_data.xlsx',2)
ret.set_index('Date', inplace=True)
del ret['SHV']
ret
# Out:
#                  BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2009-04-30  0.008993 -0.001000  0.155582  0.115190  0.138460 -0.027452
# 2009-05-31  0.053672  0.162663  0.159400  0.131918  0.028555 -0.020773
# 2009-06-30  0.005149 -0.026259 -0.022495 -0.014050  0.033516 -0.005572
# 2009-07-31  0.031284  0.018568  0.110146  0.100415  0.069191  0.008317
# 2009-08-31  0.007628 -0.040365 -0.013136  0.045031 -0.016969  0.007635
# ...              ...       ...       ...       ...       ...       ...
# 2022-04-30 -0.069696  0.056408 -0.061351 -0.067391 -0.041803 -0.042283
# 2022-05-31  0.005460  0.046131  0.006135  0.019959  0.016299  0.006184
# 2022-06-30 -0.046443 -0.075000 -0.051577 -0.087666 -0.070499 -0.008634
# 2022-07-31  0.020443 -0.019895 -0.003491  0.051688  0.066989  0.029615
# 2022-08-31 -0.051172  0.006128 -0.016767 -0.054778 -0.037825 -0.034538
#
#                  IYR       PSP       QAI       SPY       TIP
# Date
# 2009-04-30  0.296151  0.230202  0.022882  0.099346 -0.017952
# 2009-05-31  0.022727  0.053892  0.027865  0.058454  0.019967
# 2009-06-30 -0.024863  0.045449 -0.003436 -0.000655  0.001982
# 2009-07-31  0.105799  0.143247  0.015326  0.074606  0.000879
# 2009-08-31  0.131939  0.033413 -0.004151  0.036939  0.008413
# ...              ...       ...       ...       ...       ...
# 2022-04-30 -0.041305 -0.125679 -0.033398 -0.087769 -0.021831
# 2022-05-31 -0.044434  0.015084 -0.004025  0.002257 -0.009922
# 2022-06-30 -0.068911 -0.132477 -0.033681 -0.082460 -0.031155
# 2022-07-31  0.088606  0.108961  0.018822  0.092087  0.043098
# 2022-08-31 -0.054829 -0.080808 -0.008553 -0.033447 -0.018330
#
# [161 rows x 11 columns]

# %% [markdown]
# In the questions below, annualize the statistics you report.
# - Annualize the mean of monthly returns with a scaling of 12.

# %%
ret_mean = ret.mean()*12
ret_mean.head(7)
# Out:
# BWX    0.004653
# DBC    0.038846
# EEM    0.072621
# EFA    0.081124
# HYG    0.071588
# IEF    0.025833
# IYR    0.150128
# dtype: float64

# %% [markdown]
# - Annualize the volatility of monthly returns with a scaling of $\sqrt12$

# %%
ret_vol = ret.std()*m.sqrt(12)
ret_vol.head(7)
# Out:
# BWX    0.078535
# DBC    0.180186
# EEM    0.191787
# EFA    0.161885
# HYG    0.089403
# IEF    0.060077
# IYR    0.184407
# dtype: float64

# %% [markdown]
# - The Sharpe Ratio is the mean return divided by the volatility of returns.3 Accordingly, we can
# annualize the Sharpe Ratio with a scaling of sqrt(12)
# - Note that we are not scaling the raw timeseries data, just the statistics computed from it (mean, vol, Sharpe).

# %%
ret_sp_ratio = ret_mean/ret_vol
ret_sp_ratio.head(7)
# Out:
# BWX    0.059248
# DBC    0.215590
# EEM    0.378655
# EFA    0.501125
# HYG    0.800730
# IEF    0.429996
# IYR    0.814113
# dtype: float64

# %%
table = pd.concat([ret_mean, ret_vol, ret_sp_ratio], axis=1)
table = table.rename(columns={0:'Mean', 1:'Vol', 2:'Sharpe Ratio'})
table
# Out:
#          Mean       Vol  Sharpe Ratio
# BWX  0.004653  0.078535      0.059248
# DBC  0.038846  0.180186      0.215590
# EEM  0.072621  0.191787      0.378655
# EFA  0.081124  0.161885      0.501125
# HYG  0.071588  0.089403      0.800730
# IEF  0.025833  0.060077      0.429996
# IYR  0.150128  0.184407      0.814113
# PSP  0.133272  0.221299      0.602227
# QAI  0.022862  0.048879      0.467723
# SPY  0.150293  0.144811      1.037857
# TIP  0.034967  0.047833      0.731032

# %% [markdown]
# ### We are going to analyze the problem in terms of total–not excess–returns.
# - Thus, you will focus on the “Mean-Variance” section of the lecture notes, especially the formulas on slide 40.
# - In using the “total returns” tab of the data, drop the column SHV. It is our proxy for the risk-free rate, which we are ignoring in our analysis of total returns.
# - Thus, below, you are analyzing 11 risky assets–not SHV.

# %% [markdown]
# ## 1. Summary Statistics
# - Calculate and display the mean and volatility of each asset’s excess return. (Recall we use volatility to refer to standard deviation
# - Which assets have the best and worst Sharpe ratios4?

# %% [markdown]
# ## 1.(a) EXCESS RETURN TABLE

# %%
ex_ret = pd.read_excel('multi_asset_etf_data.xlsx',3)
ex_ret.set_index('Date', inplace=True)
table2 = pd.concat([ex_ret.mean()*12, ex_ret.std()*m.sqrt(12), ex_ret.mean()*12/(ex_ret.std()*m.sqrt(12))], axis=1)
table2 = table2.rename(columns={0:'Mean', 1:'Vol', 2:'Sharpe Ratio'})
table2
# Out:
#          Mean       Vol  Sharpe Ratio
# BWX  0.000003  0.078307      0.000034
# DBC  0.034196  0.180663      0.189279
# EEM  0.067971  0.192071      0.353884
# EFA  0.076474  0.162298      0.471197
# HYG  0.066938  0.089701      0.746233
# IEF  0.021182  0.059387      0.356685
# IYR  0.145477  0.184744      0.787452
# PSP  0.128622  0.221773      0.579971
# QAI  0.018212  0.049174      0.370346
# SPY  0.145643  0.145260      1.002640
# TIP  0.030317  0.047681      0.635828

# %% [markdown]
# ## 1.(b) BEST AND WORST SHARPE RATIOS

# %%
#best and worst sharpe ratio

print('Best Sharpe Ratio: ', table['Sharpe Ratio'].idxmax())
print('Worst Sharpe Ratio: ', table['Sharpe Ratio'].idxmin())
# Out:
# Best Sharpe Ratio:  SPY
# Worst Sharpe Ratio:  BWX

# %%
table.nlargest(1, 'Sharpe Ratio')
# Out:
#          Mean       Vol  Sharpe Ratio
# SPY  0.150293  0.144811      1.037857

# %%
table.nsmallest(1, 'Sharpe Ratio')
# Out:
#          Mean       Vol  Sharpe Ratio
# BWX  0.004653  0.078535      0.059248

# %% [markdown]
# ## 2. Descriptive Analysis

# %% [markdown]
# ### 2.(a) Calculate the correlation matrix of the returns. Which pair has the highest correlation? And the lowest?

# %%
corr = ret.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(4)
# Out:
# /var/folders/js/d6m3lmg13x1dqjyw_1h8pr8h0000gn/T/ipykernel_22591/1148366645.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(4)
# <style type="text/css">
# #T_61d1f_row0_col0, #T_61d1f_row1_col1, #T_61d1f_row2_col2, #T_61d1f_row3_col3, #T_61d1f_row4_col4, #T_61d1f_row5_col5, #T_61d1f_row6_col6, #T_61d1f_row7_col7, #T_61d1f_row8_col8, #T_61d1f_row9_col9, #T_61d1f_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_61d1f_row0_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_61d1f_row0_col2, #T_61d1f_row6_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_61d1f_row0_col3, #T_61d1f_row1_col3, #T_61d1f_row8_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_61d1f_row0_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_61d1f_row0_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_61d1f_row0_col6, #T_61d1f_row10_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_61d1f_row0_col7, #T_61d1f_row2_col6, #T_61d1f_row4_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_61d1f_row0_col8, #T_61d1f_row5_col10 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_61d1f_row0_col9, #T_61d1f_row1_col8 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_61d1f_row0_col10 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_61d1f_row1_col0, #T_61d1f_row1_col5, #T_61d1f_row1_col10, #T_61d1f_row5_col1, #T_61d1f_row5_col2, #T_61d1f_row5_col3, #T_61d1f_row5_col4, #T_61d1f_row5_col6, #T_61d1f_row5_col7, #T_61d1f_row5_col8, #T_61d1f_row5_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_61d1f_row1_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_61d1f_row1_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_61d1f_row1_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_61d1f_row1_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_61d1f_row1_col9 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_61d1f_row2_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_61d1f_row2_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_61d1f_row2_col3, #T_61d1f_row3_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_61d1f_row2_col4, #T_61d1f_row6_col3 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_61d1f_row2_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_61d1f_row2_col7, #T_61d1f_row7_col8 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_61d1f_row2_col8 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_61d1f_row2_col9 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_61d1f_row2_col10 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_61d1f_row3_col0, #T_61d1f_row10_col0, #T_61d1f_row10_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_61d1f_row3_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_61d1f_row3_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_61d1f_row3_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_61d1f_row3_col6 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_61d1f_row3_col7, #T_61d1f_row7_col3 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_61d1f_row3_col8 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_61d1f_row3_col9, #T_61d1f_row9_col3 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_61d1f_row3_col10, #T_61d1f_row9_col10 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_61d1f_row4_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_61d1f_row4_col2, #T_61d1f_row8_col4, #T_61d1f_row9_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_61d1f_row4_col3, #T_61d1f_row4_col9 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_61d1f_row4_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_61d1f_row4_col6, #T_61d1f_row7_col6 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_61d1f_row4_col7, #T_61d1f_row8_col7 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_61d1f_row4_col8, #T_61d1f_row10_col5 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_61d1f_row4_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_61d1f_row5_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_61d1f_row6_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_61d1f_row6_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_61d1f_row6_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_61d1f_row6_col5, #T_61d1f_row6_col10 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_61d1f_row6_col7, #T_61d1f_row6_col9 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_61d1f_row6_col8, #T_61d1f_row9_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_61d1f_row7_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_61d1f_row7_col1, #T_61d1f_row8_col6 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_61d1f_row7_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_61d1f_row7_col4, #T_61d1f_row9_col8 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_61d1f_row7_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_61d1f_row7_col9, #T_61d1f_row9_col7 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_61d1f_row7_col10 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_61d1f_row8_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_61d1f_row8_col2 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_61d1f_row8_col3 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_61d1f_row8_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_61d1f_row8_col9 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_61d1f_row8_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_61d1f_row9_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_61d1f_row9_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_61d1f_row9_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_61d1f_row9_col6 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_61d1f_row10_col1, #T_61d1f_row10_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_61d1f_row10_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_61d1f_row10_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_61d1f_row10_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_61d1f_row10_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# </style>
# <table id="T_61d1f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BWX</th>
#       <th class="col_heading level0 col1" >DBC</th>
#       <th class="col_heading level0 col2" >EEM</th>
#       <th class="col_heading level0 col3" >EFA</th>
#       <th class="col_heading level0 col4" >HYG</th>
#       <th class="col_heading level0 col5" >IEF</th>
#       <th class="col_heading level0 col6" >IYR</th>
#       <th class="col_heading level0 col7" >PSP</th>
#       <th class="col_heading level0 col8" >QAI</th>
#       <th class="col_heading level0 col9" >SPY</th>
#       <th class="col_heading level0 col10" >TIP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61d1f_level0_row0" class="row_heading level0 row0" >BWX</th>
#       <td id="T_61d1f_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_61d1f_row0_col1" class="data row0 col1" >0.3276</td>
#       <td id="T_61d1f_row0_col2" class="data row0 col2" >0.6032</td>
#       <td id="T_61d1f_row0_col3" class="data row0 col3" >0.5758</td>
#       <td id="T_61d1f_row0_col4" class="data row0 col4" >0.5375</td>
#       <td id="T_61d1f_row0_col5" class="data row0 col5" >0.3515</td>
#       <td id="T_61d1f_row0_col6" class="data row0 col6" >0.4116</td>
#       <td id="T_61d1f_row0_col7" class="data row0 col7" >0.5087</td>
#       <td id="T_61d1f_row0_col8" class="data row0 col8" >0.6412</td>
#       <td id="T_61d1f_row0_col9" class="data row0 col9" >0.4272</td>
#       <td id="T_61d1f_row0_col10" class="data row0 col10" >0.5770</td>
#     </tr>
#     <tr>
#       <th id="T_61d1f_level0_row1" class="row_heading level0 row1" >DBC</th>
#       <td id="T_61d1f_row1_col0" class="data row1 col0" >0.3276</td>
#       <td id="T_61d1f_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_61d1f_row1_col2" class="data row1 col2" >0.5646</td>
#       <td id="T_61d1f_row1_col3" class="data row1 col3" >0.5774</td>
#       <td id="T_6

# %%
corr[corr == 1] = np.nan
corr.unstack().sort_values(ascending=False)[:1]
# Out:
# PSP  EFA    0.908746
# dtype: float64

# %%
corr[corr == 1] = np.nan
corr.unstack().sort_values(ascending=True)[:1]
# Out:
# IEF  DBC   -0.405431
# dtype: float64

# %% [markdown]
# ### The highest correlation pair is PSP/EFA
# ### Lowest is IEF/DBC

# %% [markdown]
# ###  2.(b)How well have TIPS done in our sample? Have they outperformed domestic bonds? Foreign bonds?

# %%
table.loc[['TIP','IEF','BWX']]
# Out:
#          Mean       Vol  Sharpe Ratio
# TIP  0.034967  0.047833      0.731032
# IEF  0.025833  0.060077      0.429996
# BWX  0.004653  0.078535      0.059248

# %% [markdown]
# ### YES TIPS have done well compared to 7-10y UST and IG Sovereign Foreign Debt instruments. It has higher Sharpe Ratio, i.e., higher returns per unit of vol/sd.

# %% [markdown]
# ### 2.(c) Based on the data, do TIPS seem to expand the investment opportunity set, implying that Harvard should consider them as a separate asset?

# %%
corr[-1:]
# Out:
#          BWX       DBC       EEM       EFA       HYG      IEF       IYR  \
# TIP  0.57696  0.073191  0.229728  0.200071  0.308617  0.68032  0.328398
#
#           PSP       QAI       SPY  TIP
# TIP  0.228678  0.402777  0.203344  NaN

# %% [markdown]
# #### Yes, TIPS show low correlation to most of the asset, other than BWX and IEF with 57.7% and 68% correlation respectively.

# %% [markdown]
# ## 3. The MV frontier.

# %% [markdown]
# ## 3.(a) Compute and display the weights of the tangency portfolios: $\omega^t$.

# %%
def tangency_portfolio(df):
    N = df.shape[1]
    mu = df.mean() * 12 #mean
    sig = df.cov() * 12 #covariance
    sig_inv = np.linalg.inv(sig) #inverse of covariance
    
    scaling = np.ones(N)@sig_inv@mu
    
    om_t = (1/scaling) * sig_inv @ mu
    
    return om_t

omega_tangent = tangency_portfolio(ret)
omega_tangent = pd.DataFrame(omega_tangent, index=ret.columns, columns=['Weights'])
omega_tangent
# Out:
#       Weights
# BWX -1.335168
# DBC  0.239151
# EEM  0.339786
# EFA -0.117068
# HYG  1.070489
# IEF  2.457952
# IYR -0.307783
# PSP -0.513078
# QAI -3.955222
# SPY  2.430623
# TIP  0.690317

# %% [markdown]
# ## 3.(b) Compute the mean, volatility, and Sharpe ratio for the tangency portfolio corresponding to $\omega^t$

# %%
# Calclulating mean, vol and sharpe ratio of tangency portfolio

def portfolio_stats(df, weights):
    N = df.shape[1]
    mu = df.mean() * 12 #mean
    sig = df.cov() * 12 #covariance
    
    mu_p = weights.T @ mu
    sig_p = np.sqrt(weights.T @ sig @ weights)
    sharpe_p = mu_p/sig_p
    
    print('Mean: ', mu_p, ',\nVol: ', sig_p, ',\nSharpe Ratio: ', sharpe_p)

# %%
portfolio_stats(ret, omega_tangent)
# Out:
# Mean:  Weights    0.342822
# dtype: float64 ,
# Vol:            Weights
# Weights  0.175865 ,
# Sharpe Ratio:            Weights
# Weights  1.949342

# %% [markdown]
# ## The allocation.
# ### 4.(a) Compute and display the weights of MV portfolios with target returns of $μ^p = .015$

# %%
mean_target = 0.015

# %%
#Calculate the minimum variance portfolio

def min_variance_portfolio(df):
    N = df.shape[1]
    mu = df.mean() * 12 #mean
    sig = df.cov() * 12 #covariance
    sig_inv = np.linalg.inv(sig) #inverse of covariance
    
    scaling = np.ones(N) @ sig_inv @ np.ones(N)
    omega_v = (1/scaling) * sig_inv @ np.ones(N)
    
    return omega_v

omega_variance = min_variance_portfolio(ret)
omega_variance = pd.DataFrame(omega_variance, index=ret.columns, columns=['Weights'])
omega_variance.T
# Out:
#               BWX     DBC       EEM       EFA       HYG       IEF       IYR  \
# Weights -0.124649  0.0056 -0.068993  0.034347  0.119633  0.095434 -0.011567
#
#               PSP       QAI       SPY       TIP
# Weights -0.109676  0.977931 -0.067959  0.149899

# %%
ret.mean()
# Out:
# BWX    0.000388
# DBC    0.003237
# EEM    0.006052
# EFA    0.006760
# HYG    0.005966
# IEF    0.002153
# IYR    0.012511
# PSP    0.011106
# QAI    0.001905
# SPY    0.012524
# TIP    0.002914
# dtype: float64

# %%
delta = (mean_target - ret.mean().T @ omega_variance) / (ret.mean().T @ omega_tangent - ret.mean().T @ omega_variance)
delta
# Out:
# Weights    0.511554
# dtype: float64

# %%
omega_p = omega_variance + delta * (omega_tangent - omega_variance)
omega_p
# Out:
#       Weights
# BWX -0.743896
# DBC  0.125074
# EEM  0.140120
# EFA -0.043110
# HYG  0.606047
# IEF  1.303991
# IYR -0.163098
# PSP -0.316038
# QAI -1.545644
# SPY  1.210202
# TIP  0.426352

# %% [markdown]
# ### 4.(b) What is the mean, volatility, and Sharpe ratio for $\omega^p$?

# %%
#omega_p = omega_p.squeeze()
portfolio_stats(ret, omega_p)
# Out:
# Mean:  Weights    0.18
# dtype: float64 ,
# Vol:            Weights
# Weights  0.093406 ,
# Sharpe Ratio:            Weights
# Weights  1.927061

# %% [markdown]
# ### 4.(c) Discuss the allocation. In which assets is the portfolio most long? And short?

# %% [markdown]
# - The portfolio is most long in IEF which are 7-10 year USTs. and biggest short position is on QAI the diversified asset.
# - The portfolio also seems to have statistically relevant long positions in other TIP and HYG bonds along with a much higher allocation to SPY

# %%
omega_p.sort_values(by='Weights', ascending=False).T
# Out:
#               IEF       SPY       HYG       TIP      EEM       DBC      EFA  \
# Weights  1.303991  1.210202  0.606047  0.426352  0.14012  0.125074 -0.04311
#
#               IYR       PSP       BWX       QAI
# Weights -0.163098 -0.316038 -0.743896 -1.545644

# %% [markdown]
# ### 4.(d) Does this line up with which assets have the strongest Sharpe ratios?

# %% [markdown]
# No, it doesnt seem to follow the Sharpe ratio.

# %%
table.sort_values(by='Sharpe Ratio', ascending=False).T
# Out:
#                    SPY       IYR       HYG       TIP       PSP       EFA  \
# Mean          0.150293  0.150128  0.071588  0.034967  0.133272  0.081124
# Vol           0.144811  0.184407  0.089403  0.047833  0.221299  0.161885
# Sharpe Ratio  1.037857  0.814113  0.800730  0.731032  0.602227  0.501125
#
#                    QAI       IEF       EEM       DBC       BWX
# Mean          0.022862  0.025833  0.072621  0.038846  0.004653
# Vol           0.048879  0.060077  0.191787  0.180186  0.078535
# Sharpe Ratio  0.467723  0.429996  0.378655  0.215590  0.059248

# %% [markdown]
# ## 5. Simple Portfolios

# %% [markdown]
# ### 5.(a) Calculate the performance of the equally-weighted portfolio over the sample. Rescale the entire weighting vector to have target mean $μ^p = .015$. Report its mean, volatility, and Sharpe ratio.

# %%
weights_equal = np.ones(len(omega_tangent))/len(omega_tangent)
weights_equal
# Out:
# array([0.09090909, 0.09090909, 0.09090909, 0.09090909, 0.09090909,
#        0.09090909, 0.09090909, 0.09090909, 0.09090909, 0.09090909,
#        0.09090909])

# %%
weights_equal = weights_equal * (mean_target*12 / (ret_mean @ weights_equal))
weights_equal
portfolio_stats(ret, weights_equal)
# Out:
# Mean:  0.17999999999999997 ,
# Vol:  0.25166093350987956 ,
# Sharpe Ratio:  0.7152480819711082

# %% [markdown]
# ## 5.(b) Calculate the performance of the “risk-parity” portfolio over the sample. Risk-parity is a term used in a variety of ways, but here we have in mind setting the weight of the portfolio to be proportional to the inverse of its full-sample volatility estimate. $w^i = 1/\sigma_i$ This will give the weight vector, $\omega$, but you will need to rescale it to have a target mean of $μ^p = .015$.

# %%
weight_parity = 1/ret_vol
weight_parity = weight_parity * (mean_target*12 / (ret_mean @ weight_parity))
weight_parity
# Out:
# BWX    0.379571
# DBC    0.165439
# EEM    0.155431
# EFA    0.184142
# HYG    0.333430
# IEF    0.496193
# IYR    0.161652
# PSP    0.134704
# QAI    0.609866
# SPY    0.205852
# TIP    0.623205
# dtype: float64

# %%
portfolio_stats(ret, weight_parity)
# Out:
# Mean:  0.17999999999999997 ,
# Vol:  0.23560722729202044 ,
# Sharpe Ratio:  0.763983355132401

# %% [markdown]
# ### 5.(c) How does these compare to the MV portfolio from problem 2.4?

# %%
portfolio_stats(ret, omega_tangent)
# Out:
# Mean:  Weights    0.342822
# dtype: float64 ,
# Vol:            Weights
# Weights  0.175865 ,
# Sharpe Ratio:            Weights
# Weights  1.949342

# %% [markdown]
# #### The sharpe ratio is lower compare to the MV portfolio. The Vols and Mean are individually lower compared to MV potfolio.
# #### No short positions!

# %% [markdown]
# ### 6. Assess how much the Sharpe Ratio goes down if we drop TIPS from the investment set, (and just have a 10-asset problem.) See how much it decreases the performance statistics in 2.4. And how much worse is the performance in 3.3?

# %% [markdown]
# ### The sharpe ratio went down from 1.95 to around 1.91 after we dropped TIPS from the investment set

# %%
ret_tips = ret.drop(['TIP'], axis=1)
ret_tips.shape
omega_v_tips = min_variance_portfolio(ret_tips)
omega_t_tips = tangency_portfolio(ret_tips)
delta_tips = (mean_target - ret_tips.mean().T @ omega_v_tips) / (ret_tips.mean().T @ omega_t_tips - ret_tips.mean().T @ omega_v_tips)
omega_p_tips = omega_v_tips + delta_tips * (omega_t_tips - omega_v_tips)

portfolio_stats(ret_tips, omega_p_tips)
# Out:
# Mean:  0.18000000000000002 ,
# Vol:  0.09408853907751885 ,
# Sharpe Ratio:  1.913091666262342

# %% [markdown]
# ### 7.Out-of-Sample Performance. Let’s divide the sample to both compute a portfolio and then check its performance out of sample.

# %% [markdown]
# ### 7.(a) Using only data through the end of 2021, compute $\omega^p for μ^p $= .015, allocating to all 11 assets.

# %%
ret_2021 = pd.read_excel('multi_asset_etf_data.xlsx',2)
ret_2021.set_index('Date', inplace=True)
del ret_2021['SHV']

ret_2021.index = pd.to_datetime(ret_2021.index)
#remove the rows above 2022-01-01

ret_2021 = ret_2021[ret_2021.index < '2022-01-01']
ret_2021
# Out:
#                  BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2009-04-30  0.008993 -0.001000  0.155582  0.115190  0.138460 -0.027452
# 2009-05-31  0.053672  0.162663  0.159400  0.131918  0.028555 -0.020773
# 2009-06-30  0.005149 -0.026259 -0.022495 -0.014050  0.033516 -0.005572
# 2009-07-31  0.031284  0.018568  0.110146  0.100415  0.069191  0.008317
# 2009-08-31  0.007628 -0.040365 -0.013136  0.045031 -0.016969  0.007635
# ...              ...       ...       ...       ...       ...       ...
# 2021-08-31 -0.009051 -0.016410  0.015698  0.014467  0.006087 -0.003944
# 2021-09-30 -0.023686  0.052138 -0.038733 -0.032614 -0.003701 -0.015971
# 2021-10-31 -0.004493  0.057978  0.010718  0.031791 -0.003108 -0.004429
# 2021-11-30 -0.006168 -0.087588 -0.040848 -0.045347 -0.011690  0.010921
# 2021-12-31 -0.001628  0.066735  0.015071  0.043909  0.022841 -0.005240
#
#                  IYR       PSP       QAI       SPY       TIP
# Date
# 2009-04-30  0.296151  0.230202  0.022882  0.099346 -0.017952
# 2009-05-31  0.022727  0.053892  0.027865  0.058454  0.019967
# 2009-06-30 -0.024863  0.045449 -0.003436 -0.000655  0.001982
# 2009-07-31  0.105799  0.143247  0.015326  0.074606  0.000879
# 2009-08-31  0.131939  0.033413 -0.004151  0.036939  0.008413
# ...              ...       ...       ...       ...       ...
# 2021-08-31  0.019396  0.014277  0.001244  0.029760 -0.001641
# 2021-09-30 -0.056269 -0.083231 -0.013358 -0.046605 -0.007801
# 2021-10-31  0.072761  0.094793  0.010705  0.070163  0.011095
# 2021-11-30 -0.024126 -0.042073 -0.014953 -0.008035  0.008651
# 2021-12-31  0.094691  0.019423  0.008165  0.046248  0.004029
#
# [153 rows x 11 columns]

# %%
omega_v_2021 = min_variance_portfolio(ret_2021)
omega_t_2021 = tangency_portfolio(ret_2021)
delta_2021 = (mean_target - ret_2021.mean().T @ omega_v_2021) / (ret_2021.mean().T @ omega_t_2021 - ret_2021.mean().T @ omega_v_2021)
omega_p_2021 = omega_v_2021 + delta_2021 * (omega_t_2021 - omega_v_2021)

pd.DataFrame(omega_p_2021, index=ret_2021.columns, columns=['Weights'])
# Out:
#       Weights
# BWX -0.260550
# DBC -0.013134
# EEM  0.003842
# EFA -0.058326
# HYG  0.665042
# IEF  1.186294
# IYR -0.257773
# PSP -0.087996
# QAI -1.587112
# SPY  1.109137
# TIP  0.300576

# %% [markdown]
# ### 7.(b) Using those weights, calculate the portfolio’s Sharpe ratio within that sample, through the end of 2021.

# %%
portfolio_stats(ret_2021, omega_p_2021)
# Out:
# Mean:  0.18000000000000005 ,
# Vol:  0.07798828578469066 ,
# Sharpe Ratio:  2.308038934166887

# %% [markdown]
# ### 7.(c)Again using those weights, (derived using data through 2021,) calculate the portfolio’s Sharpe ratio based on performance in 2022.

# %%
ret_2022 = pd.read_excel('multi_asset_etf_data.xlsx',2)
ret_2022.set_index('Date', inplace=True)
ret_2022.index = pd.to_datetime(ret_2022.index)
ret_2022 = ret_2022[ret_2022.index >= '2022-01-01']

omega_v_2022 = min_variance_portfolio(ret_2022)
omega_t_2022 = tangency_portfolio(ret_2022)
delta_2022 = (mean_target - ret_2022.mean().T @ omega_v_2022) / (ret_2022.mean().T @ omega_t_2022 - ret_2022.mean().T @ omega_v_2022)
omega_p_2022 = omega_v_2022 + delta_2022 * (omega_t_2022 - omega_v_2022)

pd.DataFrame(omega_p_2022, index=ret_2022.columns, columns=['Weights'])
# Out:
#       Weights
# BWX -0.697581
# DBC  0.355494
# EEM  0.165229
# EFA -1.483127
# HYG  0.915300
# IEF  1.527563
# IYR  0.197113
# PSP  0.246686
# QAI  0.671317
# SHV  0.391893
# SPY  0.107860
# TIP -1.397747

# %%
portfolio_stats(ret_2022, omega_p_2022)
# Out:
# Mean:  0.17999999999999985 ,
# Vol:  2.7563081848147856e-09 ,
# Sharpe Ratio:  65304743.85689757
