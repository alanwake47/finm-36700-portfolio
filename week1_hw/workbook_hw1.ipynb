# %% [markdown]
# # 2 Mean-Variance Optimization
#
# - The time-series data gives monthly returns for the 11 asset classes and a short-term Treasury-bill
# fund return, (“SHV”,) which we consider as the risk-free rate.
# - The data is provided in total returns, (in which case you should ignore the SHV column,) as
# well as excess returns, (where SHV has been subtracted from the other columns.)
# - These are nominal returns—they are not adjusted for inflation, and in our calculations we are not making any adjustment for inflation.

# %%
import pandas as pd
import numpy as np
import math as m

# %%
ret = pd.read_excel('multi_asset_etf_data.xlsx',2)
ret.set_index('Date', inplace=True)
del ret['SHV']
ret
# Out:
#                  BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2009-04-30  0.008993 -0.001000  0.155582  0.115190  0.138460 -0.027452
# 2009-05-31  0.053672  0.162663  0.159400  0.131918  0.028555 -0.020773
# 2009-06-30  0.005149 -0.026259 -0.022495 -0.014050  0.033516 -0.005572
# 2009-07-31  0.031284  0.018568  0.110146  0.100415  0.069191  0.008317
# 2009-08-31  0.007628 -0.040365 -0.013136  0.045031 -0.016969  0.007635
# ...              ...       ...       ...       ...       ...       ...
# 2022-04-30 -0.069696  0.056408 -0.061351 -0.067391 -0.041803 -0.042283
# 2022-05-31  0.005460  0.046131  0.006135  0.019959  0.016299  0.006184
# 2022-06-30 -0.046443 -0.075000 -0.051577 -0.087666 -0.070499 -0.008634
# 2022-07-31  0.020443 -0.019895 -0.003491  0.051688  0.066989  0.029615
# 2022-08-31 -0.051172  0.006128 -0.016767 -0.054778 -0.037825 -0.034538
#
#                  IYR       PSP       QAI       SPY       TIP
# Date
# 2009-04-30  0.296151  0.230202  0.022882  0.099346 -0.017952
# 2009-05-31  0.022727  0.053892  0.027865  0.058454  0.019967
# 2009-06-30 -0.024863  0.045449 -0.003436 -0.000655  0.001982
# 2009-07-31  0.105799  0.143247  0.015326  0.074606  0.000879
# 2009-08-31  0.131939  0.033413 -0.004151  0.036939  0.008413
# ...              ...       ...       ...       ...       ...
# 2022-04-30 -0.041305 -0.125679 -0.033398 -0.087769 -0.021831
# 2022-05-31 -0.044434  0.015084 -0.004025  0.002257 -0.009922
# 2022-06-30 -0.068911 -0.132477 -0.033681 -0.082460 -0.031155
# 2022-07-31  0.088606  0.108961  0.018822  0.092087  0.043098
# 2022-08-31 -0.054829 -0.080808 -0.008553 -0.033447 -0.018330
#
# [161 rows x 11 columns]

# %% [markdown]
# In the questions below, annualize the statistics you report.
# - Annualize the mean of monthly returns with a scaling of 12.

# %%
ret_mean = ret.mean()*12
ret_mean.head(7)
# Out:
# BWX    0.004653
# DBC    0.038846
# EEM    0.072621
# EFA    0.081124
# HYG    0.071588
# IEF    0.025833
# IYR    0.150128
# dtype: float64

# %% [markdown]
# - Annualize the volatility of monthly returns with a scaling of sqrt(12)

# %%
ret_vol = ret.std()*m.sqrt(12)
ret_vol.head(7)
# Out:
# BWX    0.078535
# DBC    0.180186
# EEM    0.191787
# EFA    0.161885
# HYG    0.089403
# IEF    0.060077
# IYR    0.184407
# dtype: float64

# %% [markdown]
# - The Sharpe Ratio is the mean return divided by the volatility of returns.3 Accordingly, we can
# annualize the Sharpe Ratio with a scaling of sqrt(12)
# - Note that we are not scaling the raw timeseries data, just the statistics computed from it (mean, vol, Sharpe).

# %%
ret_sp_ratio = ret_mean/ret_vol
ret_sp_ratio.head(7)
# Out:
# BWX    0.059248
# DBC    0.215590
# EEM    0.378655
# EFA    0.501125
# HYG    0.800730
# IEF    0.429996
# IYR    0.814113
# dtype: float64

# %%
table = pd.concat([ret_mean, ret_vol, ret_sp_ratio], axis=1)
table = table.rename(columns={0:'Mean', 1:'Vol', 2:'Sharpe Ratio'})
table
# Out:
#          Mean       Vol  Sharpe Ratio
# BWX  0.004653  0.078535      0.059248
# DBC  0.038846  0.180186      0.215590
# EEM  0.072621  0.191787      0.378655
# EFA  0.081124  0.161885      0.501125
# HYG  0.071588  0.089403      0.800730
# IEF  0.025833  0.060077      0.429996
# IYR  0.150128  0.184407      0.814113
# PSP  0.133272  0.221299      0.602227
# QAI  0.022862  0.048879      0.467723
# SPY  0.150293  0.144811      1.037857
# TIP  0.034967  0.047833      0.731032

# %% [markdown]
# ### We are going to analyze the problem in terms of total–not excess–returns.
# - Thus, you will focus on the “Mean-Variance” section of the lecture notes, especially the formulas on slide 40.
# - In using the “total returns” tab of the data, drop the column SHV. It is our proxy for the risk-free rate, which we are ignoring in our analysis of total returns.
# - Thus, below, you are analyzing 11 risky assets–not SHV.

# %% [markdown]
# ## Summary Statistics
# - Calculate and display the mean and volatility of each asset’s excess return. (Recall we use volatility to refer to standard deviation
# - Which assets have the best and worst Sharpe ratios4?

# %% [markdown]
# ## EXCESS RETURN TABLE

# %%
ex_ret = pd.read_excel('multi_asset_etf_data.xlsx',2)
ex_ret.set_index('Date', inplace=True)
table2 = pd.concat([ex_ret.mean()*12, ex_ret.std()*m.sqrt(12), ex_ret.mean()*12/ex_ret.std()*m.sqrt(12)], axis=1)
table2 = table2.rename(columns={0:'Mean', 1:'Vol', 2:'Sharpe Ratio'})
table2
# Out:
#          Mean       Vol  Sharpe Ratio
# BWX  0.004653  0.078535      0.710975
# DBC  0.038846  0.180186      2.587078
# EEM  0.072621  0.191787      4.543859
# EFA  0.081124  0.161885      6.013500
# HYG  0.071588  0.089403      9.608761
# IEF  0.025833  0.060077      5.159952
# IYR  0.150128  0.184407      9.769352
# PSP  0.133272  0.221299      7.226724
# QAI  0.022862  0.048879      5.612681
# SHV  0.004650  0.002655     21.021168
# SPY  0.150293  0.144811     12.454283
# TIP  0.034967  0.047833      8.772378

# %% [markdown]
# ## BEST AND WORST SHARPE RATIOS

# %%
mx = 0
for i in ret_sp_ratio.columns:
    for j in ret_sp_ratio.index:
        if ret_sp_ratio[i][j] > mx:
            mx = ret_sp_ratio[i][j]
            print(i,j,mx)

for i in ret_sp_ratio.columns:
    for j in ret_sp_ratio.index:
        if ret_sp_ratio[i][j] < mx:
            mx = ret_sp_ratio[i][j]
            print(i,j,mx)
# Out:
# BWX 2009 1.473573765893245
# BWX 2017 2.12831079522236
# EEM 2009 2.9048742790086686
# EEM 2017 4.373726566663796
# EFA 2017 5.401778475971366
# BWX 2009 1.473573765893245
# BWX 2010 0.37136671537219906
# BWX 2013 -0.44287256008243037
# BWX 2015 -1.31710438873816
# BWX 2021 -1.6615972438482791
# BWX 2022 -3.12409318340419
# EEM 2022 -3.4697137640502755

# %%
for i in ret_sp_ratio.columns:
    print(i,max(ret_sp_ratio[i]))
    print(i,min(ret_sp_ratio[i]))
# Out:
# BWX 2.12831079522236
# BWX -3.12409318340419
# DBC 2.0964146421015486
# DBC -2.0441561566425688
# EEM 4.373726566663796
# EEM -3.4697137640502755
# EFA 5.401778475971366
# EFA -1.8656038709074871
# HYG 3.0065793062046353
# HYG -1.1913816824509524
# IEF 2.4164843577282062
# IEF -1.9679010961037662
# IYR 2.602368442466794
# IYR -1.2177621083991075
# PSP 2.7356768774725744
# PSP -2.0290306050497184
# QAI 4.877099937513971
# QAI -2.2502462813226836
# SPY 5.109942524436184
# SPY -1.089806688746128
# TIP 3.103365083223062
# TIP -1.3549608117907266

# %% [markdown]
# ### Descriptive Analysis
#
# - Calculate the correlation matrix of the returns. Which pair has the highest correlation? And the lowest?
# - How well have TIPS done in our sample? Have they outperformed domestic bonds? Foreign bonds?
# - Based on the data, do TIPS seem to expand the investment opportunity set, implying that Harvard should consider them as a separate asset?

# %%
corr = ret.corr()
corr = corr.drop('Month', axis=1)
corr = corr.drop('Month', axis=0)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0a6da_row0_col0, #T_0a6da_row1_col1, #T_0a6da_row2_col2, #T_0a6da_row3_col3, #T_0a6da_row4_col4, #T_0a6da_row5_col5, #T_0a6da_row6_col6, #T_0a6da_row7_col7, #T_0a6da_row8_col8, #T_0a6da_row9_col9, #T_0a6da_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0a6da_row0_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_0a6da_row0_col2, #T_0a6da_row6_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_0a6da_row0_col3, #T_0a6da_row1_col3, #T_0a6da_row8_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_0a6da_row0_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_0a6da_row0_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_0a6da_row0_col6, #T_0a6da_row10_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_0a6da_row0_col7, #T_0a6da_row2_col6, #T_0a6da_row4_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_0a6da_row0_col8, #T_0a6da_row5_col10 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_0a6da_row0_col9, #T_0a6da_row1_col8 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_0a6da_row0_col10 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_0a6da_row1_col0, #T_0a6da_row1_col5, #T_0a6da_row1_col10, #T_0a6da_row5_col1, #T_0a6da_row5_col2, #T_0a6da_row5_col3, #T_0a6da_row5_col4, #T_0a6da_row5_col6, #T_0a6da_row5_col7, #T_0a6da_row5_col8, #T_0a6da_row5_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0a6da_row1_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_0a6da_row1_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_0a6da_row1_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_0a6da_row1_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_0a6da_row1_col9 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_0a6da_row2_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_0a6da_row2_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_0a6da_row2_col3, #T_0a6da_row3_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_0a6da_row2_col4, #T_0a6da_row6_col3 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_0a6da_row2_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_0a6da_row2_col7, #T_0a6da_row7_col8 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_0a6da_row2_col8 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_0a6da_row2_col9 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_0a6da_row2_col10 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_0a6da_row3_col0, #T_0a6da_row10_col0, #T_0a6da_row10_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_0a6da_row3_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_0a6da_row3_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_0a6da_row3_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_0a6da_row3_col6 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_0a6da_row3_col7, #T_0a6da_row7_col3 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_0a6da_row3_col8 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_0a6da_row3_col9, #T_0a6da_row9_col3 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_0a6da_row3_col10, #T_0a6da_row9_col10 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_0a6da_row4_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_0a6da_row4_col2, #T_0a6da_row8_col4, #T_0a6da_row9_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_0a6da_row4_col3, #T_0a6da_row4_col9 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_0a6da_row4_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_0a6da_row4_col6, #T_0a6da_row7_col6 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_0a6da_row4_col7, #T_0a6da_row8_col7 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_0a6da_row4_col8, #T_0a6da_row10_col5 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_0a6da_row4_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_0a6da_row5_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_0a6da_row6_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_0a6da_row6_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_0a6da_row6_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_0a6da_row6_col5, #T_0a6da_row6_col10 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_0a6da_row6_col7, #T_0a6da_row6_col9 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_0a6da_row6_col8, #T_0a6da_row9_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_0a6da_row7_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_0a6da_row7_col1, #T_0a6da_row8_col6 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_0a6da_row7_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_0a6da_row7_col4, #T_0a6da_row9_col8 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_0a6da_row7_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_0a6da_row7_col9, #T_0a6da_row9_col7 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_0a6da_row7_col10 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_0a6da_row8_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_0a6da_row8_col2 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_0a6da_row8_col3 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_0a6da_row8_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_0a6da_row8_col9 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_0a6da_row8_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_0a6da_row9_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_0a6da_row9_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_0a6da_row9_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_0a6da_row9_col6 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_0a6da_row10_col1, #T_0a6da_row10_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_0a6da_row10_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_0a6da_row10_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_0a6da_row10_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_0a6da_row10_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# </style>
# <table id="T_0a6da_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BWX</th>
#       <th class="col_heading level0 col1" >DBC</th>
#       <th class="col_heading level0 col2" >EEM</th>
#       <th class="col_heading level0 col3" >EFA</th>
#       <th class="col_heading level0 col4" >HYG</th>
#       <th class="col_heading level0 col5" >IEF</th>
#       <th class="col_heading level0 col6" >IYR</th>
#       <th class="col_heading level0 col7" >PSP</th>
#       <th class="col_heading level0 col8" >QAI</th>
#       <th class="col_heading level0 col9" >SPY</th>
#       <th class="col_heading level0 col10" >TIP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a6da_level0_row0" class="row_heading level0 row0" >BWX</th>
#       <td id="T_0a6da_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0a6da_row0_col1" class="data row0 col1" >0.327560</td>
#       <td id="T_0a6da_row0_col2" class="data row0 col2" >0.603227</td>
#       <td id="T_0a6da_row0_col3" class="data row0 col3" >0.575751</td>
#       <td id="T_0a6da_row0_col4" class="data row0 col4" >0.537479</td>
#       <td id="T_0a6da_row0_col5" class="data row0 col5" >0.351529</td>
#       <td id="T_0a6da_row0_col6" class="data row0 col6" >0.411551</td>
#       <td id="T_0a6da_row0_col7" class="data row0 col7" >0.508670</td>
#       <td id="T_0a6da_row0_col8" class="data row0 col8" >0.641232</td>
#       <td id="T_0a6da_row0_col9" class="data row0 col9" >0.427215</td>
#       <td id="T_0a6da_row0_col10" class="data row0 col10" >0.576960</td>
#     </tr>
#     <tr>
#       <th id="T_0a6da_level0_row1" class="row_heading level0 row1" >DBC</th>
#       <td id="T_0a6da_row1_col0" class="data row1 col0" >0.327560</td>
#       <td id="T_0a6da_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0a6da_row1_col2" class="data row1 col2" >0.564615</td>
#       <td id="T_0a6da_row1_col3" class="data row1 col3" >0

# %%
corr.style.highlight_max(color = 'darkblue', axis = 0)
# Out:
# <style type="text/css">
# #T_9f265_row3_col1, #T_9f265_row3_col2, #T_9f265_row3_col7, #T_9f265_row3_col8, #T_9f265_row4_col6, #T_9f265_row5_col10, #T_9f265_row7_col3, #T_9f265_row7_col4, #T_9f265_row7_col9, #T_9f265_row8_col0, #T_9f265_row10_col5 {
#   background-color: darkblue;
# }
# </style>
# <table id="T_9f265_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BWX</th>
#       <th class="col_heading level0 col1" >DBC</th>
#       <th class="col_heading level0 col2" >EEM</th>
#       <th class="col_heading level0 col3" >EFA</th>
#       <th class="col_heading level0 col4" >HYG</th>
#       <th class="col_heading level0 col5" >IEF</th>
#       <th class="col_heading level0 col6" >IYR</th>
#       <th class="col_heading level0 col7" >PSP</th>
#       <th class="col_heading level0 col8" >QAI</th>
#       <th class="col_heading level0 col9" >SPY</th>
#       <th class="col_heading level0 col10" >TIP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f265_level0_row0" class="row_heading level0 row0" >BWX</th>
#       <td id="T_9f265_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_9f265_row0_col1" class="data row0 col1" >0.327560</td>
#       <td id="T_9f265_row0_col2" class="data row0 col2" >0.603227</td>
#       <td id="T_9f265_row0_col3" class="data row0 col3" >0.575751</td>
#       <td id="T_9f265_row0_col4" class="data row0 col4" >0.537479</td>
#       <td id="T_9f265_row0_col5" class="data row0 col5" >0.351529</td>
#       <td id="T_9f265_row0_col6" class="data row0 col6" >0.411551</td>
#       <td id="T_9f265_row0_col7" class="data row0 col7" >0.508670</td>
#       <td id="T_9f265_row0_col8" class="data row0 col8" >0.641232</td>
#       <td id="T_9f265_row0_col9" class="data row0 col9" >0.427215</td>
#       <td id="T_9f265_row0_col10" class="data row0 col10" >0.576960</td>
#     </tr>
#     <tr>
#       <th id="T_9f265_level0_row1" class="row_heading level0 row1" >DBC</th>
#       <td id="T_9f265_row1_col0" class="data row1 col0" >0.327560</td>
#       <td id="T_9f265_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_9f265_row1_col2" class="data row1 col2" >0.564615</td>
#       <td id="T_9f265_row1_col3" class="data row1 col3" >0.577386</td>
#       <td id="T_9f265_row1_col4" class="data row1 col4" >0.450744</td>
#       <td id="T_9f265_row1_col5" class="data row1 col5" >-0.405431</td>
#       <td id="T_9f265_row1_col6" class="data row1 col6" >0.284214</td>
#       <td id="T_9f265_row1_col7" class="data row1 col7" >0.483768</td>
#       <td id="T_9f265_row1_col8" class="data row1 col8" >0.530539</td>
#       <td id="T_9f265_row1_col9" class="data row1 col9" >0.490920</td>
#       <td id="T_9f265_row1_col10" class="data row1 col10" >0.073191</td>
#     </tr>
#     <tr>
#       <th id="T_9f265_level0_row2" class="row_heading level0 row2" >EEM</th>
#       <td id="T_9f265_row2_col0" class="data row2 col0" >0.603227</td>
#       <td id="T_9f265_row2_col1" class="data row2 col1" >0.564615</td>
#       <td id="T_9f265_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_9f265_row2_col3" class="data row2 col3" >0.846499</td>
#       <td id="T_9f265_row2_col4" class="data row2 col4" >0.724708</td>
#       <td id="T_9f265_row2_col5" class="data row2 col5" >-0.237574</td>
#       <td id="T_9f265_row2_col6" class="data row2 col6" >0.598835</td>
#       <td id="T_9f265_row2_col7" class="data row2 col7" >0.786492</td>
#       <td id="T_9f265_row2_col8" class="data row2 col8" >0.792416</td>
#       <td id="T_9f265_row2_col9" class="data row2 col9" >0.734649</td>
#       <td id="T_9f265_row2_col10" class="data row2 col10" >0.229728</td>
#     </tr>
#     <tr>
#       <th id="T_9f265_level0_
row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_9f265_row6_col7" class="data row6 col7" >0.745726</td>
#       <td id="T_9f265_row6_col8" class="data row6 col8" >0.623356</td>
#       <td id="T_9f265_row6_col9" class="data row6 col9" >0.740340</td>
#       <td id="T_9f265_row6_col10" class="data row6 col10" >0.328398</td>
#     </tr>
#     <tr>
#       <th id="T_9f265_level0_row7" class="row_heading level0 row7" >PSP</th>
#       <td id="T_9f265_row7_col0" class="data row7 col0" >0.508670</td>
#       <td id="T_9f265_row7_col1" class="data row7 col1" >0.483768</td>
#       <td id="T_9f265_row7_col2" class="data row7 col2" >0.786492</td>
#       <td id="T_9f265_row7_col3" class="data row7 col3" >0.908746</td>
#       <td id="T_9f265_row7_col4" class="data row7 col4" >0.823979</td>
#       <td id="T_9f265_row7_col5" class="data row7 col5" >-0.245902</td>
#       <td id="T_9f265_row7_col6" class="data row7 col6" >0.745726</td>
#       <td id="T_9f265_row7_col7" class="data row7 col7" >0.000000</td>
#       <td id="T_9f265_row7_col8" class="data row7 col8" >0.824637</td>
#       <td id="T_9f265_row7_col9" class="data row7 col9" >0.903421</td>
#       <td id="T_9f265_row7_col10" class="data row7 col10" >0

# %%
corr.style.highlight_min(color = 'darkgreen', axis = 0)
# Out:
# <style type="text/css">
# #T_51c8b_row0_col0, #T_51c8b_row1_col5, #T_51c8b_row5_col1, #T_51c8b_row5_col2, #T_51c8b_row5_col3, #T_51c8b_row5_col4, #T_51c8b_row5_col6, #T_51c8b_row5_col7, #T_51c8b_row5_col8, #T_51c8b_row5_col9, #T_51c8b_row10_col10 {
#   background-color: darkgreen;
# }
# </style>
# <table id="T_51c8b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BWX</th>
#       <th class="col_heading level0 col1" >DBC</th>
#       <th class="col_heading level0 col2" >EEM</th>
#       <th class="col_heading level0 col3" >EFA</th>
#       <th class="col_heading level0 col4" >HYG</th>
#       <th class="col_heading level0 col5" >IEF</th>
#       <th class="col_heading level0 col6" >IYR</th>
#       <th class="col_heading level0 col7" >PSP</th>
#       <th class="col_heading level0 col8" >QAI</th>
#       <th class="col_heading level0 col9" >SPY</th>
#       <th class="col_heading level0 col10" >TIP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51c8b_level0_row0" class="row_heading level0 row0" >BWX</th>
#       <td id="T_51c8b_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_51c8b_row0_col1" class="data row0 col1" >0.327560</td>
#       <td id="T_51c8b_row0_col2" class="data row0 col2" >0.603227</td>
#       <td id="T_51c8b_row0_col3" class="data row0 col3" >0.575751</td>
#       <td id="T_51c8b_row0_col4" class="data row0 col4" >0.537479</td>
#       <td id="T_51c8b_row0_col5" class="data row0 col5" >0.351529</td>
#       <td id="T_51c8b_row0_col6" class="data row0 col6" >0.411551</td>
#       <td id="T_51c8b_row0_col7" class="data row0 col7" >0.508670</td>
#       <td id="T_51c8b_row0_col8" class="data row0 col8" >0.641232</td>
#       <td id="T_51c8b_row0_col9" class="data row0 col9" >0.427215</td>
#       <td id="T_51c8b_row0_col10" class="data row0 col10" >0.576960</td>
#     </tr>
#     <tr>
#       <th id="T_51c8b_level0_row1" class="row_heading level0 row1" >DBC</th>
#       <td id="T_51c8b_row1_col0" class="data row1 col0" >0.327560</td>
#       <td id="T_51c8b_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_51c8b_level0_row5" class="row_heading level0 row5" >IEF</th>
#       <td id="T_51c8b_row5_col0" class="data row5 col0" >0.351529</td>
#       <td id="T_51c8b_row5_col1" class="data row5 col1" >-0.405431</td>
#       <td id="T_51c8b_row5_col2" class="data row5 col2" >-0.237574</td>
#       <td id="T_51c8b_row5_col3" class="data row5 col3" >-0.264846</td>
#       <td id="T_51c8b_row5_col4" class="data row5 col4" >-0.088828</td>
#       <td id="T_51c8b_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_51c8b_row5_col6" class="data row5 col6" >-0.018565</td>
#       <td id="T_51c8b_row5_col7" class="data row5 col7" >-0.245902</td>
#       <td id="T_51c8b_row5_col8" class="data row5 col8" >-0.039956</td>
#       <td id="T_51c8b_row5_col9" class="data row5 col9" >-0.269163</td>
#       <td id="T_51c8b_row5_col10" class="data row5 col10" >0.680320</td>
#     </tr>
#     <tr>
#       <th id="T_51c8b_level0_row6" class="row_heading level0 row6" >IYR</th>
#       <td id="T_51c8b_row6_col0" class="data row6 col0" >0.411551</td>
#       <td id="T_51c8b_row6_col1" class="data row6 col1" >0.284214</td>
#       <td id="T_51c8b_row6_col2" class="data row6 col2" >0.598835</td>
#       <td id="T_51c8b_row6_col3" class="data row6 col3" >0.680872</td>
#       <td id="T_51c8b_row6_col4" class="data row6 col4" >0.746952</td>
#       <td id="T_51c8b_row6_col5" class="data row6 col5" >-0.018565</td>
#       <td id="T_51c8b_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_51c8b_row6_col7" class="data row6 col7" >0.745726</td>
#       <td id="T_51c8b_row6_col8" class="data row6 col8" >0.623356</td>
#       <td id="T_51c8b_row6_col9" class="data row6 col9" >0.740340</td>
#       <td id="T_51c8b_row6_col10" class="data row6 col10" >0.328398</td>
#     </tr>
#     <tr>
#       <th id="T_51c8b_level0_row7" class="row_heading level0 row7" >PSP</th>
#       <td id="T_51c8b_row7_col0" class="data row7 col0" >0.508670</td>
#       <td id="T_51c8b_row7_col1" class="data row7 col1" >0.483768</td>
#       <td id="T_51c8b_row7_col2" class="data row7 col2" >0.786492</td>
#       <td id="T_51c8b_row7_col3" class="data row7 col3" >0.908746</td>
#       <td id="T_51c8b_row7_col4" class="data row7 col4" >0.823979</td>
#       <td id="T_51c8b_row7_col5" class="data row7 col5" >-0.245902</td>
#       <td id="T_51c8b_row7_col6" class="data row7 col6" >0.745726</td>
#       <td id="T_51c8b_row7_col7" class="data row7 col7" >0.000000</td>
#       <td id="T_51c8b_row7_col8" class="data row7 col8" >0.824637</td>
#       <td id="T_51c8b_row7_col9" class="data row7 col9" >0.903421</td>
#       <td id="T_51c8b_row7_col10" class="data row7 col10" >

# %%
#change columns of matrix to 0
for i in ret_sp_ratio.columns:
    corr[i][i] = 0

#Find the pair with the highest correlation
mx=0
for i in corr.columns:
    for j in corr.index:
        if corr[i][j] > mx:
            mx = corr[i][j]
            print(i,j,mx)

mx=0
for i in corr.columns:
    for j in corr.index:
        if corr[i][j] < mx:
            mx = corr[i][j]
            print(i,j,mx)
# Out:
# BWX DBC 0.3275599883565334
# BWX EEM 0.6032271886405398
# BWX QAI 0.6412318778006221
# EEM EFA 0.8464993277043764
# EFA PSP 0.9087460438502873
# DBC IEF -0.40543101061677644

# %%
corr.max().max()
# Out:
# 0.9087460438502873
